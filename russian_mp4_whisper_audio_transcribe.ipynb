# %% [markdown]
# <a href="https://colab.research.google.com/github/MLegkovskis/whisper-russian-mp4-transcribe/blob/main/russian_mp4_whisper_audio_transcribe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🔧 system + python deps (Whisper uses GPU automatically if available)
# !apt -y update -qq
# !apt -y install -qq ffmpeg

# !pip -q install --upgrade pip
# !pip -q install openai-whisper regex tqdm

import os, re
from pathlib import Path
from tqdm import tqdm
import whisper
import torch

print("CUDA available:", torch.cuda.is_available())
# Out:
# 35 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done
# CUDA available: True

# %%
# ⚙️ params
VIDEOS_DIR = Path("stepik_videos")  # folder with your .mp4 files
TEXTS_DIR  = Path("texts")         # output .txt folder (one file per video)
MODEL_NAME = "large-v3"            # tiny/base/small/medium/large-v3
LANGUAGE   = "ru"                  # Russian transcription only

TEXTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
# minimal command detection (since commands are spoken)
COMMAND_VERBS = r"(kubectl|helm|minikube|kubeadm|docker|podman|ctr|crictl|systemctl|journalctl|apt|yum|dnf|pacman|brew|snap|pip|python3?|node|npm|npx|curl|wget|git|ssh|scp|ls|cd|cat|nano|vim|vi|less|tail|head|echo|tee|sed|awk|grep|tar|zip|unzip|make|cmake|kubens|kubectx|kind|kustomize|terraform|istioctl|k9s)"
CMD_RE = re.compile(rf"(?:^|\s)(?:sudo\s+)?{COMMAND_VERBS}\b.*", re.IGNORECASE)

def load_model(name: str):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"→ loading whisper {name} on {device}")
    return whisper.load_model(name, device=device)

def transcribe_ru(model, video_path: Path):
    return model.transcribe(str(video_path), task="transcribe", language=LANGUAGE)

def segments_to_timestamped_text(segments):
    lines = []
    for s in segments:
        start = s.get("start", 0.0)
        end = s.get("end", 0.0)
        text = (s.get("text") or "").strip()
        lines.append(f"[{start:7.2f}–{end:7.2f}] {text}")
    return "\n".join(lines)

def detect_commands_from_segments(segments):
    seen, out = set(), []
    for s in segments:
        t = (s.get("text") or "").strip()
        if not t:
            continue
        # find command-like phrase inside the spoken text
        m = CMD_RE.search(t)
        if m:
            cmd = re.sub(r"\s+", " ", m.group(0).strip())
            key = cmd.lower()
            if key not in seen:
                seen.add(key)
                out.append(cmd)
    return out

# %%
videos = sorted([p for p in VIDEOS_DIR.glob("*") if p.suffix.lower() in {".mp4", ".mkv", ".mov", ".m4v"}])
assert videos, f"No videos found in {VIDEOS_DIR}. Put your files there."

model = load_model(MODEL_NAME)

for vid in videos:
    print(f"\n====== {vid.name} ======")
    res = transcribe_ru(model, vid)
    segs = res.get("segments", [])

    transcript_ru = segments_to_timestamped_text(segs)
    commands = detect_commands_from_segments(segs)

    out_txt = TEXTS_DIR / f"{vid.stem}.txt"
    with open(out_txt, "w", encoding="utf-8") as f:
        f.write(f"# {vid.name}\n")
        f.write(f"Model: {MODEL_NAME}\n\n")
        f.write("## Transcript (RU)\n")
        f.write(transcript_ru)
        f.write("\n\n## Commands (detected)\n")
        if commands:
            for c in commands:
                f.write(f"- {c}\n")
        else:
            f.write("- (none detected)\n")

    print(f"→ wrote {out_txt}")

print("\n✅ done. One .txt per video is in ./texts/")
# Out:
# → loading whisper large-v3 on cuda
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:14<00:00, 41.3MiB/s]
# ====== Шаг 1 Autocomplete Stepik.mp4 ======
# → wrote texts/Шаг 1 Autocomplete Stepik.txt
#
# ====== Шаг 1 Build Stepik.mp4 ======
# → wrote texts/Шаг 1 Build Stepik.txt
#
# ====== Шаг 1 ConfigMap Монтирование фаилов Stepik.mp4 ======
# → wrote texts/Шаг 1 ConfigMap Монтирование фаилов Stepik.txt
#
# ====== Шаг 1 CronJob Stepik.mp4 ======
# → wrote texts/Шаг 1 CronJob Stepik.txt
#
# ====== Шаг 1 DaemonSet Stepik.mp4 ======
# → wrote texts/Шаг 1 DaemonSet Stepik.txt
#
# ====== Шаг 1 Deploy Stepik.mp4 ======
# → wrote texts/Шаг 1 Deploy Stepik.txt
#
# ====== Шаг 1 Deployment Stepik.mp4 ======
# → wrote texts/Шаг 1 Deployment Stepik.txt
#
# ====== Шаг 1 Helm изнутри Stepik.mp4 ======
# → wrote texts/Шаг 1 Helm изнутри Stepik.txt
#
# ====== Шаг 1 Ingress Stepik.mp4 ======
# → wrote texts/Шаг 1 Ingress Stepik.txt
#
# ====== Шаг 1 Job Stepik.mp4 ======
# → wrote texts/Шаг 1 Job Stepik.txt
#
# ====== Шаг 1 Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 1 Kubernetes Stepik.txt
#
# ====== Шаг 1 Multistage Stepik.mp4 ======
# → wrote texts/Шаг 1 Multistage Stepik.txt
#
# ====== Шаг 1 Namespace Stepik.mp4 ======
# → wrote texts/Шаг 1 Namespace Stepik.txt
#
# ====== Шаг 1 Pod Stepik.mp4 ======
# → wrote texts/Шаг 1 Pod Stepik.txt
#
# ====== Шаг 1 Secret Переменные окружения Stepik.mp4 ======
# → wrote texts/Шаг 1 Secret Переменные окружения Stepik.txt
#
# ====== Шаг 1 UI для Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 1 UI для Kubernetes Stepik.txt
#
# ====== Шаг 1 Values Системные переменные Stepik.mp4 ======
# → wrote texts/Шаг 1 Values Системные переменные Stepik.txt
#
# ====== Шаг 1 alias Stepik.mp4 ======
# → wrote texts/Шаг 1 alias Stepik.txt
#
# ====== Шаг 1 kns ktx Stepik.mp4 ======
# → wrote texts/Шаг 1 kns ktx Stepik.txt
#
# ====== Шаг 1 kubeconfig Stepik.mp4 ======
# → wrote texts/Шаг 1 kubeconfig Stepik.txt
#
# ====== Шаг 1 kubectl debug и nsenter Stepik.mp4 ======
# → wrote texts/Шаг 1 kubectl debug и nsenter Stepik.txt
#
# ====== Шаг 1 kubespray Stepik.mp4 ======
# → wrote texts/Шаг 1 kubespray Stepik.txt
#
# ====== Шаг 1 unit-tests Stepik.mp4 ======
# → wrote texts/Шаг 1 unit-tests Stepik.txt
#
# ====== Шаг 1 Архитектура Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 1 Архитектура Kubernetes Stepik.txt
#
# ====== Шаг 1 Введение Stepik(1).mp4 ======
# → wrote texts/Шаг 1 Введение Stepik(1).txt
#
# ====== Шаг 1 Введение Stepik.mp4 ======
# → wrote texts/Шаг 1 Введение Stepik.txt
#
# ====== Шаг 1 Декларативныи подход Stepik.mp4 ======
# → wrote texts/Шаг 1 Декларативныи подход Stepik.txt
#
# ====== Шаг 1 Для чего нужен Helm Stepik.mp4 ======
# → wrote texts/Шаг 1 Для чего нужен Helm Stepik.txt
#
# ====== Шаг 1 Докер Stepik.mp4 ======
# → wrote texts/Шаг 1 Докер Stepik.txt
#
# ====== Шаг 1 Другие контроллеры Stepik.mp4 ======
# → wrote texts/Шаг 1 Другие контроллеры Stepik.txt
#
# ====== Шаг 1 Идем дальше Stepik.mp4 ======
# → wrote texts/Шаг 1 Идем дальше Stepik.txt
#
# ====== Шаг 1 Контеинеры Stepik.mp4 ======
# → wrote texts/Шаг 1 Контеинеры Stepik.txt
#
# ====== Шаг 1 Контроллеры ReplicaSet Stepik.mp4 ======
# → wrote texts/Шаг 1 Контроллеры ReplicaSet Stepik.txt
#
# ====== Шаг 1 Образы для курса Stepik.mp4 ======
# → wrote texts/Шаг 1 Образы для курса Stepik.txt
#
# ====== Шаг 1 Первыи чарт Stepik.mp4 ======
# → wrote texts/Шаг 1 Первыи чарт Stepik.txt
#
# ====== Шаг 1 Плагины kubectl krew Stepik.mp4 ======
# → wrote texts/Шаг 1 Плагины kubectl krew Stepik.txt
#
# ====== Шаг 1 Плагины для VS Code Stepik.mp4 ======
# → wrote texts/Шаг 1 Плагины для VS Code Stepik.txt
#
# ====== Шаг 1 Пробы Stepik.mp4 ======
# → wrote texts/Шаг 1 Пробы Stepik.txt
#
# ====== Шаг 1 Публикация образов в Dockerhub Stepik.mp4 ======
# → wrote texts/Шаг 1 Публикация образов в Dockerhub Stepik.txt
#
# ====== Шаг 1 Типы Сервисов Stepik.mp4 ======
# → wrote texts/Шаг 1 Типы Сервисов Stepik.txt
#
# ====== Шаг 1 Управление ресурсами Stepik.mp4 ======
# → wrote texts/Шаг 1 Управление ресурсами Stepik.txt
#
# ====== Шаг 1 Условия Stepik.mp4 ======
# → wrote texts/Шаг 1 Условия Stepik.txt
#
# ====== Шаг 1 Установка Runner Stepik.mp4 ======
# → wrote texts/Шаг 1 Установка Runner Stepik.txt
#
# ====== Шаг 1 Установка кластера Stepik.mp4 ======
# → wrote texts/Шаг 1 Установка кластера Stepik.txt
#
# ====== Шаг 1 Флоу Синтаксис Gitlab CI Stepik.mp4 ======
# → wrote texts/Шаг 1 Флоу Синтаксис Gitlab CI Stepik.txt
#
# ====== Шаг 1 Функции Stepik.mp4 ======
# → wrote texts/Шаг 1 Функции Stepik.txt
#
# ====== Шаг 1 Циклы Stepik.mp4 ======
# → wrote texts/Шаг 1 Циклы Stepik.txt
#
# ====== Шаг 10 Deployment Stepik.mp4 ======
# → wrote texts/Шаг 10 Deployment Stepik.txt
#
# ====== Шаг 11 Контроллеры ReplicaSet Stepik.mp4 ======
# → wrote texts/Шаг 11 Контроллеры ReplicaSet Stepik.txt
#
# ====== Шаг 2 Build Stepik.mp4 ======
# → wrote texts/Шаг 2 Build Stepik.txt
#
# ====== Шаг 2 ConfigMap Монтирование фаилов Stepik.mp4 ======
# → wrote texts/Шаг 2 ConfigMap Монтирование фаилов Stepik.txt
#
# ====== Шаг 2 CronJob Stepik.mp4 ======
# → wrote texts/Шаг 2 CronJob Stepik.txt
#
# ====== Шаг 2 DaemonSet Stepik.mp4 ======
# → wrote texts/Шаг 2 DaemonSet Stepik.txt
#
# ====== Шаг 2 Deploy Stepik.mp4 ======
# → wrote texts/Шаг 2 Deploy Stepik.txt
#
# ====== Шаг 2 Ingress Stepik.mp4 ======
# → wrote texts/Шаг 2 Ingress Stepik.txt
#
# ====== Шаг 2 Job Stepik.mp4 ======
# → wrote texts/Шаг 2 Job Stepik.txt
#
# ====== Шаг 2 Multistage Stepik.mp4 ======
# → wrote texts/Шаг 2 Multistage Stepik.txt
#
# ====== Шаг 2 Secret Переменные окружения Stepik.mp4 ======
# → wrote texts/Шаг 2 Secret Переменные окружения Stepik.txt
#
# ====== Шаг 2 UI для Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 2 UI для Kubernetes Stepik.txt
#
# ====== Шаг 2 Values Системные переменные Stepik.mp4 ======
# → wrote texts/Шаг 2 Values Системные переменные Stepik.txt
#
# ====== Шаг 2 kns ktx Stepik.mp4 ======
# → wrote texts/Шаг 2 kns ktx Stepik.txt
#
# ====== Шаг 2 kubeconfig Stepik.mp4 ======
# → wrote texts/Шаг 2 kubeconfig Stepik.txt
#
# ====== Шаг 2 kubectl debug и nsenter Stepik.mp4 ======
# → wrote texts/Шаг 2 kubectl debug и nsenter Stepik.txt
#
# ====== Шаг 2 Архитектура Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 2 Архитектура Kubernetes Stepik.txt
#
# ====== Шаг 2 Введение Stepik.mp4 ======
# → wrote texts/Шаг 2 Введение Stepik.txt
#
# ====== Шаг 2 Дебаг Stepik.mp4 ======
# → wrote texts/Шаг 2 Дебаг Stepik.txt
#
# ====== Шаг 2 Декларативныи подход Stepik.mp4 ======
# → wrote texts/Шаг 2 Декларативныи подход Stepik.txt
#
# ====== Шаг 2 Для чего нужен Helm Stepik.mp4 ======
# → wrote texts/Шаг 2 Для чего нужен Helm Stepik.txt
#
# ====== Шаг 2 Докер Stepik.mp4 ======
# → wrote texts/Шаг 2 Докер Stepik.txt
#
# ====== Шаг 2 Контеинеры Stepik.mp4 ======
# → wrote texts/Шаг 2 Контеинеры Stepik.txt
#
# ====== Шаг 2 Первыи чарт Stepik.mp4 ======
# → wrote texts/Шаг 2 Первыи чарт Stepik.txt
#
# ====== Шаг 2 Плагины kubectl krew Stepik.mp4 ======
# → wrote texts/Шаг 2 Плагины kubectl krew Stepik.txt
#
# ====== Шаг 2 Пробы Stepik.mp4 ======
# → wrote texts/Шаг 2 Пробы Stepik.txt
#
# ====== Шаг 2 Сетевое взаимодеиствие Подов в k8s Stepik.mp4 ======
# → wrote texts/Шаг 2 Сетевое взаимодеиствие Подов в k8s Stepik.txt
#
# ====== Шаг 2 Типы Сервисов Stepik.mp4 ======
# → wrote texts/Шаг 2 Типы Сервисов Stepik.txt
#
# ====== Шаг 2 Управление ресурсами Stepik.mp4 ======
# → wrote texts/Шаг 2 Управление ресурсами Stepik.txt
#
# ====== Шаг 2 Установка Runner Stepik.mp4 ======
# → wrote texts/Шаг 2 Установка Runner Stepik.txt
#
# ====== Шаг 2 Установка кластера Stepik.mp4 ======
# → wrote texts/Шаг 2 Установка кластера Stepik.txt
#
# ====== Шаг 2 Флоу Синтаксис Gitlab CI Stepik.mp4 ======
# → wrote texts/Шаг 2 Флоу Синтаксис Gitlab CI Stepik.txt
#
# ====== Шаг 2 Функции Stepik.mp4 ======
# → wrote texts/Шаг 2 Функции Stepik.txt
#
# ====== Шаг 2 Циклы Stepik.mp4 ======
# → wrote texts/Шаг 2 Циклы Stepik.txt
#
# ====== Шаг 3 Build Stepik.mp4 ======
# → wrote texts/Шаг 3 Build Stepik.txt
#
# ====== Шаг 3 ConfigMap Монтирование фаилов Stepik.mp4 ======
# → wrote texts/Шаг 3 ConfigMap Монтирование фаилов Stepik.txt
#
# ====== Шаг 3 CronJob Stepik.mp4 ======
# → wrote texts/Шаг 3 CronJob Stepik.txt
#
# ====== Шаг 3 DaemonSet Stepik.mp4 ======
# → wrote texts/Шаг 3 DaemonSet Stepik.txt
#
# ====== Шаг 3 Deploy Stepik.mp4 ======
# → wrote texts/Шаг 3 Deploy Stepik.txt
#
# ====== Шаг 3 Deployment Stepik.mp4 ======
# → wrote texts/Шаг 3 Deployment Stepik.txt
#
# ====== Шаг 3 Ingress Stepik.mp4 ======
# → wrote texts/Шаг 3 Ingress Stepik.txt
#
# ====== Шаг 3 Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 3 Kubernetes Stepik.txt
#
# ====== Шаг 3 Namespace Stepik.mp4 ======
# → wrote texts/Шаг 3 Namespace Stepik.txt
#
# ====== Шаг 3 Pod Stepik.mp4 ======
# → wrote texts/Шаг 3 Pod Stepik.txt
#
# ====== Шаг 3 Secret Переменные окружения Stepik.mp4 ======
# → wrote texts/Шаг 3 Secret Переменные окружения Stepik.txt
#
# ====== Шаг 3 UI для Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 3 UI для Kubernetes Stepik.txt
#
# ====== Шаг 3 Values Системные переменные Stepik.mp4 ======
# → wrote texts/Шаг 3 Values Системные переменные Stepik.txt
#
# ====== Шаг 3 kubeconfig Stepik.mp4 ======
# → wrote texts/Шаг 3 kubeconfig Stepik.txt
#
# ====== Шаг 3 Введение Stepik.mp4 ======
# → wrote texts/Шаг 3 Введение Stepik.txt
#
# ====== Шаг 3 Дебаг Stepik.mp4 ======
# → wrote texts/Шаг 3 Дебаг Stepik.txt
#
# ====== Шаг 3 Для чего нужен Helm Stepik.mp4 ======
# → wrote texts/Шаг 3 Для чего нужен Helm Stepik.txt
#
# ====== Шаг 3 Докер Stepik.mp4 ======
# → wrote texts/Шаг 3 Докер Stepik.txt
#
# ====== Шаг 3 Контеинеры Stepik.mp4 ======
# → wrote texts/Шаг 3 Контеинеры Stepik.txt
#
# ====== Шаг 3 Образы для курса Stepik.mp4 ======
# → wrote texts/Шаг 3 Образы для курса Stepik.txt
#
# ====== Шаг 3 Первыи чарт Stepik.mp4 ======
# → wrote texts/Шаг 3 Первыи чарт Stepik.txt
#
# ====== Шаг 3 Пробы Stepik.mp4 ======
# → wrote texts/Шаг 3 Пробы Stepik.txt
#
# ====== Шаг 3 Сетевое взаимодеиствие Подов в k8s Stepik.mp4 ======
# → wrote texts/Шаг 3 Сетевое взаимодеиствие Подов в k8s Stepik.txt
#
# ====== Шаг 3 Типы Сервисов Stepik.mp4 ======
# → wrote texts/Шаг 3 Типы Сервисов Stepik.txt
#
# ====== Шаг 3 Управление ресурсами Stepik.mp4 ======
# → wrote texts/Шаг 3 Управление ресурсами Stepik.txt
#
# ====== Шаг 3 Установка Runner Stepik.mp4 ======
# → wrote texts/Шаг 3 Установка Runner Stepik.txt
#
# ====== Шаг 3 Флоу Синтаксис Gitlab CI Stepik.mp4 ======
# → wrote texts/Шаг 3 Флоу Синтаксис Gitlab CI Stepik.txt
#
# ====== Шаг 3 Функции Stepik.mp4 ======
# → wrote texts/Шаг 3 Функции Stepik.txt
#
# ====== Шаг 4 DaemonSet Stepik.mp4 ======
# → wrote texts/Шаг 4 DaemonSet Stepik.txt
#
# ====== Шаг 4 Ingress Stepik.mp4 ======
# → wrote texts/Шаг 4 Ingress Stepik.txt
#
# ====== Шаг 4 Secret Переменные окружения Stepik.mp4 ======
# → wrote texts/Шаг 4 Secret Переменные окружения Stepik.txt
#
# ====== Шаг 4 UI для Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 4 UI для Kubernetes Stepik.txt
#
# ====== Шаг 4 Дебаг Stepik.mp4 ======
# → wrote texts/Шаг 4 Дебаг Stepik.txt
#
# ====== Шаг 4 Для чего нужен Helm Stepik.mp4 ======
# → wrote texts/Шаг 4 Для чего нужен Helm Stepik.txt
#
# ====== Шаг 4 Докер Stepik.mp4 ======
# → wrote texts/Шаг 4 Докер Stepik.txt
#
# ====== Шаг 4 Пробы Stepik.mp4 ======
# → wrote texts/Шаг 4 Пробы Stepik.txt
#
# ====== Шаг 4 Сетевое взаимодеиствие Подов в k8s Stepik.mp4 ======
# → wrote texts/Шаг 4 Сетевое взаимодеиствие Подов в k8s Stepik.txt
#
# ====== Шаг 4 Типы Сервисов Stepik.mp4 ======
# → wrote texts/Шаг 4 Типы Сервисов Stepik.txt
#
# ====== Шаг 4 Управление ресурсами Stepik.mp4 ======
# → wrote texts/Шаг 4 Управление ресурсами Stepik.txt
#
# ====== Шаг 4 Установка кластера Stepik.mp4 ======
# → wrote texts/Шаг 4 Установка кластера Stepik.txt
#
# ====== Шаг 4 Флоу Синтаксис Gitlab CI Stepik.mp4 ======
# → wrote texts/Шаг 4 Флоу Синтаксис Gitlab CI Stepik.txt
#
# ====== Шаг 5 Build Stepik.mp4 ======
# → wrote texts/Шаг 5 Build Stepik.txt
#
# ====== Шаг 5 Deployment Stepik.mp4 ======
# → wrote texts/Шаг 5 Deployment Stepik.txt
#
# ====== Шаг 5 Ingress Stepik.mp4 ======
# → wrote texts/Шаг 5 Ingress Stepik.txt
#
# ====== Шаг 5 Kubernetes Stepik.mp4 ======
# → wrote texts/Шаг 5 Kubernetes Stepik.txt
#
# ====== Шаг 5 Pod Stepik.mp4 ======
# → wrote texts/Шаг 5 Pod Stepik.txt
#
# ====== Шаг 5 Secret Переменные окружения Stepik.mp4 ======
# → wrote texts/Шаг 5 Secret Переменные окружения Stepik.txt
#
# ====== Шаг 5 Дебаг Stepik.mp4 ======
# → wrote texts/Шаг 5 Дебаг Stepik.txt
#
# ====== Шаг 5 Докер Stepik.mp4 ======
